# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))
    
#     tf.nn.sampled_softmax_loss(weights, biases, inputs, 
#                                labels, num_sampled, num_classes, 
#                                num_true=1, sampled_values=None, 
#                                remove_accidental_hits=True, 
#                                partition_strategy='mod', name='sampled_softmax_loss')

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.371122
# Nearest to while: loos, duddy, exit, symbolise, maitreya, weight, cnet, slavery,
# Nearest to years: watersheds, ise, stupa, firefighting, bukharin, shikai, abbot, thinkers,
# Nearest to american: nsted, kelly, linear, disciplinary, notched, testosterone, opal, cdma,
# Nearest to are: constricted, muds, neurotic, swallows, ethene, points, entebbe, kd,
# Nearest to with: elas, startled, hoffman, loses, confronted, fluctuated, formulation, ifor,
# Nearest to may: landmass, precluded, krush, cathedral, snatch, valerius, diplomas, fugitives,
# Nearest to and: geos, awry, robotic, stylish, summons, ratify, wounding, laszlo,
# Nearest to who: cage, rural, aap, ceremonies, warehouses, totalitarianism, rifts, soulful,
# Nearest to were: madness, reception, dragster, nb, dec, titan, specially, mira,
# Nearest to from: public, terra, hexokinase, freedoms, distributions, conventional, korps, tempered,
# Nearest to if: cheer, bach, pseudopods, uncommonly, cantonese, kampong, hispano, reasoned,
# Nearest to the: viscous, meltdown, resistive, pompous, millwall, mostar, tangle, regions,
# Nearest to all: pok, motala, adversaries, vinton, avec, collingwood, overlooked, geospatial,
# Nearest to as: pyrotechnics, pinter, ministries, government, incubation, although, statist, wad,
# Nearest to more: debate, screenshots, spanned, atiyah, stacy, reconstituted, willfully, cause,
# Nearest to two: stems, bower, lenny, starboard, trajectory, flows, arnold, vacuole,
# Average loss at step 2000: 4.362229
# Average loss at step 4000: 3.865776
# Average loss at step 6000: 3.787337
# Average loss at step 8000: 3.686442
# Average loss at step 10000: 3.613798
# Nearest to while: duddy, nervousness, loos, attachments, fastest, switches, mujibur, composing,
# Nearest to years: lard, lisbon, bukharin, thinkers, firefighting, database, ise, columbanus,
# Nearest to american: disciplinary, linear, nsted, fortify, usmc, hetzel, opal, dynamics,
# Nearest to are: were, is, have, was, testimonium, beard, sassanid, sicilies,
# Nearest to with: in, by, mckinley, for, penalty, postscript, between, or,
# Nearest to may: can, could, might, will, would, lorica, must, griffith,
# Nearest to and: or, ipx, who, which, specimens, graf, pyramids, s,
# Nearest to who: he, aap, also, and, arrayed, cage, nay, norepinephrine,
# Nearest to were: are, was, have, okeh, uttering, purple, authenticated, is,
# Nearest to from: in, on, superclass, by, phrase, stage, with, beira,
# Nearest to if: snoop, includes, cheer, nevertheless, dab, harald, accademia, meteorite,
# Nearest to the: a, this, its, his, regions, their, any, commons,
# Nearest to all: these, filtering, sorting, some, asserting, extremely, rightness, wftu,
# Nearest to as: staring, flybys, jeffery, with, venturing, dieter, by, sem,
# Nearest to more: debate, ron, cavett, benzodiazepines, workshops, atiyah, cause, spanned,
# Nearest to two: three, four, five, six, eight, seven, zero, nine,
# Average loss at step 12000: 3.604950
# Average loss at step 14000: 3.566551
# Average loss at step 16000: 3.407701
# Average loss at step 18000: 3.456571
# Average loss at step 20000: 3.540059
# Nearest to while: duddy, nervousness, loos, fastest, switches, and, weight, mujibur,
# Nearest to years: days, lard, lisbon, firefighting, cookbooks, abolitionists, thinkers, hoffer,
# Nearest to american: german, russian, french, disciplinary, usmc, british, linear, english,
# Nearest to are: were, is, have, pivot, be, was, emeritus, other,
# Nearest to with: between, by, in, for, during, from, penalty, across,
# Nearest to may: can, would, could, will, must, should, might, lorica,
# Nearest to and: or, in, but, at, against, which, while, for,
# Nearest to who: he, she, they, which, also, then, there, retrospective,
# Nearest to were: are, was, had, have, be, by, being, is,
# Nearest to from: into, at, in, between, through, by, with, punts,
# Nearest to if: dab, nevertheless, snoop, accademia, but, atypical, fulfill, cheer,
# Nearest to the: their, its, this, his, an, caller, a, another,
# Nearest to all: these, some, those, many, filtering, marquise, extremely, rightness,
# Nearest to as: prefixed, gripped, contracting, flipped, alleviation, ozzie, staring, brat,
# Nearest to more: most, debate, less, workshops, gauthier, benzodiazepines, cavett, ionospheric,
# Nearest to two: four, three, five, six, one, seven, eight, zero,
# Average loss at step 22000: 3.500505
# Average loss at step 24000: 3.488352
# Average loss at step 26000: 3.482565
# Average loss at step 28000: 3.481940
# Average loss at step 30000: 3.501612
# Nearest to while: switches, duddy, when, but, piracy, however, where, although,
# Nearest to years: days, lard, abolitionists, months, thinkers, lisbon, firefighting, whom,
# Nearest to american: german, french, russian, english, australian, british, disciplinary, fortify,
# Nearest to are: were, have, is, these, fiqh, include, those, although,
# Nearest to with: between, without, across, postscript, gastrointestinal, against, by, among,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to and: or, but, in, niz, from, of, negotiating, filler,
# Nearest to who: he, they, she, also, which, there, it, textiles,
# Nearest to were: are, was, have, had, being, been, although, these,
# Nearest to from: into, between, in, under, on, through, after, of,
# Nearest to if: when, dab, where, although, will, but, can, snoop,
# Nearest to the: its, their, his, a, some, these, astatine, any,
# Nearest to all: some, these, those, any, out, many, ars, extremely,
# Nearest to as: contracting, by, jamaicans, plugged, with, supporter, daggers, postmodernists,
# Nearest to more: less, most, very, debate, workshops, contends, rather, inv,
# Nearest to two: four, three, one, five, seven, six, eight, nine,
# Average loss at step 32000: 3.502681
# Average loss at step 34000: 3.491740
# Average loss at step 36000: 3.453073
# Average loss at step 38000: 3.304362
# Average loss at step 40000: 3.427965
# Nearest to while: although, however, when, but, were, through, switches, duddy,
# Nearest to years: days, months, abolitionists, lard, lisbon, decades, thinkers, bukharin,
# Nearest to american: australian, german, russian, british, french, english, disciplinary, bryn,
# Nearest to are: were, have, is, include, be, being, these, including,
# Nearest to with: between, by, without, in, against, asa, when, during,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Nearest to and: or, but, where, through, however, like, macleod, in,
# Nearest to who: he, they, which, often, she, also, never, vitreous,
# Nearest to were: are, have, was, being, had, although, be, while,
# Nearest to from: into, through, in, between, of, punts, beira, fulfills,
# Nearest to if: when, is, where, dab, for, snoop, though, fulfill,
# Nearest to the: its, their, this, his, a, each, any, another,
# Nearest to all: both, these, any, mail, each, some, those, out,
# Nearest to as: by, ozzie, when, borgia, mom, flybys, extremism, warning,
# Nearest to more: less, most, very, contends, ionospheric, rather, workshops, debate,
# Nearest to two: four, three, five, seven, six, one, eight, nine,
# Average loss at step 42000: 3.434373
# Average loss at step 44000: 3.453756
# Average loss at step 46000: 3.449806
# Average loss at step 48000: 3.351424
# Average loss at step 50000: 3.381232
# Nearest to while: when, however, but, although, where, though, after, and,
# Nearest to years: days, months, abolitionists, decades, lard, minutes, lisbon, bukharin,
# Nearest to american: australian, german, russian, international, english, british, french, catalana,
# Nearest to are: were, is, have, include, these, be, those, sicilies,
# Nearest to with: between, against, across, by, without, bodied, tiff, falcon,
# Nearest to may: can, would, will, should, must, could, might, cannot,
# Nearest to and: or, but, of, however, while, in, including, anita,
# Nearest to who: he, which, she, they, never, mcenroe, often, also,
# Nearest to were: are, have, was, be, had, been, being, including,
# Nearest to from: into, through, at, fulfills, in, under, beira, marin,
# Nearest to if: when, where, dab, although, fulfill, snoop, so, will,
# Nearest to the: its, this, their, a, his, some, an, chemotherapeutic,
# Nearest to all: both, each, any, mail, fulcher, those, some, unclear,
# Nearest to as: sentencing, contracting, genevieve, plugged, pinker, latgale, utilizes, flybys,
# Nearest to more: less, most, very, contends, rather, better, ionospheric, connects,
# Nearest to two: three, six, seven, four, five, one, eight, zero,
# Average loss at step 52000: 3.437765
# Average loss at step 54000: 3.429685
# Average loss at step 56000: 3.439662
# Average loss at step 58000: 3.397960
# Average loss at step 60000: 3.392170
# Nearest to while: although, when, but, though, however, after, before, were,
# Nearest to years: days, months, decades, abolitionists, minutes, year, lard, weeks,
# Nearest to american: australian, british, english, german, indian, russian, international, dutch,
# Nearest to are: were, is, have, including, include, these, dino, be,
# Nearest to with: between, mckinley, isometric, crematorium, by, when, without, gastrointestinal,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Nearest to and: or, but, including, than, rodin, however, although, include,
# Nearest to who: he, which, still, now, never, generally, often, she,
# Nearest to were: are, was, have, including, had, although, been, while,
# Nearest to from: into, through, under, attending, in, between, fulfills, on,
# Nearest to if: when, where, though, dab, although, fulfill, snoop, since,
# Nearest to the: their, its, a, his, some, this, showcasing, our,
# Nearest to all: those, some, many, any, these, every, both, various,
# Nearest to as: quisling, sentencing, quite, flybys, teaspoon, undergraduates, wha, dieter,
# Nearest to more: less, most, very, rather, longer, better, larger, debate,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Average loss at step 62000: 3.238934
# Average loss at step 64000: 3.255216
# Average loss at step 66000: 3.402677
# Average loss at step 68000: 3.392972
# Average loss at step 70000: 3.356398
# Nearest to while: although, however, when, though, but, where, and, before,
# Nearest to years: days, months, decades, minutes, abolitionists, year, times, km,
# Nearest to american: english, australian, british, german, prion, arab, dutch, indian,
# Nearest to are: were, include, is, have, these, although, be, including,
# Nearest to with: between, without, biqa, into, gastrointestinal, against, when, by,
# Nearest to may: can, will, would, could, must, might, should, cannot,
# Nearest to and: or, while, but, including, like, which, pournelle, anita,
# Nearest to who: he, still, generally, never, they, she, now, which,
# Nearest to were: are, was, have, be, had, been, although, these,
# Nearest to from: through, into, under, in, without, between, punts, anthropologist,
# Nearest to if: when, where, though, dab, sprouts, because, while, could,
# Nearest to the: their, its, a, this, these, our, any, your,
# Nearest to all: some, many, various, every, any, both, most, each,
# Nearest to as: contracting, plugged, like, groceries, faustus, borgia, is, cautions,
# Nearest to more: less, most, very, longer, rather, better, smaller, greater,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Average loss at step 72000: 3.374081
# Average loss at step 74000: 3.344508
# Average loss at step 76000: 3.315744
# Average loss at step 78000: 3.347917
# Average loss at step 80000: 3.376617
# Nearest to while: although, though, when, but, however, after, and, before,
# Nearest to years: days, months, decades, minutes, year, times, abolitionists, weeks,
# Nearest to american: british, german, english, australian, french, russian, canadian, international,
# Nearest to are: were, have, include, is, including, contain, these, although,
# Nearest to with: between, when, mckinley, borg, penalty, among, in, pavel,
# Nearest to may: can, will, would, could, must, might, should, cannot,
# Nearest to and: or, but, including, while, pournelle, by, regan, eliyahu,
# Nearest to who: he, still, she, they, never, often, textiles, actually,
# Nearest to were: are, was, have, had, being, be, although, became,
# Nearest to from: through, into, under, after, between, in, beira, across,
# Nearest to if: when, though, where, because, since, before, although, snoop,
# Nearest to the: its, their, his, a, this, glaciations, disaccharide, each,
# Nearest to all: both, various, every, any, many, some, each, most,
# Nearest to as: bd, utilizes, genevieve, saxe, monists, daggers, cautions, personas,
# Nearest to more: less, very, most, longer, rather, greater, quite, smaller,
# Nearest to two: three, four, six, five, one, seven, eight, nine,
# Average loss at step 82000: 3.411992
# Average loss at step 84000: 3.412795
# Average loss at step 86000: 3.385294
# Average loss at step 88000: 3.355838
# Average loss at step 90000: 3.366511
# Nearest to while: although, when, though, before, however, but, after, during,
# Nearest to years: days, months, decades, minutes, year, weeks, centuries, abolitionists,
# Nearest to american: british, german, french, australian, english, canadian, russian, italian,
# Nearest to are: were, is, these, include, have, contain, although, those,
# Nearest to with: between, in, without, mckinley, during, by, across, from,
# Nearest to may: can, could, would, must, will, might, should, cannot,
# Nearest to and: or, including, but, while, anita, vs, through, impacted,
# Nearest to who: he, often, still, never, which, she, they, actually,
# Nearest to were: are, had, was, have, although, while, these, being,
# Nearest to from: through, into, beira, under, between, bleachers, after, toward,
# Nearest to if: when, since, where, though, although, sprouts, so, before,
# Nearest to the: its, materially, this, his, our, a, their, your,
# Nearest to all: both, many, some, various, several, every, most, any,
# Nearest to as: utilizes, bd, personas, genevieve, timbers, bloodless, higgs, flybys,
# Nearest to more: less, very, greater, longer, rather, most, too, better,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Average loss at step 92000: 3.398654
# Average loss at step 94000: 3.250267
# Average loss at step 96000: 3.359822
# Average loss at step 98000: 3.234554
# Average loss at step 100000: 3.355052
# Nearest to while: when, although, though, but, where, however, before, and,
# Nearest to years: days, decades, months, year, minutes, seconds, hours, weeks,
# Nearest to american: british, canadian, russian, australian, french, german, english, italian,
# Nearest to are: were, have, is, contain, be, these, although, include,
# Nearest to with: between, mckinley, without, in, gastrointestinal, isometric, into, contains,
# Nearest to may: can, could, must, should, might, would, will, cannot,
# Nearest to and: or, but, however, while, although, nor, of, including,
# Nearest to who: he, still, never, actually, she, often, which, wim,
# Nearest to were: are, was, although, these, have, including, being, is,
# Nearest to from: into, through, beira, fulfills, in, between, within, marin,
# Nearest to if: when, where, though, since, sprouts, before, so, while,
# Nearest to the: your, their, its, a, our, his, jia, my,
# Nearest to all: every, various, both, these, many, several, any, some,
# Nearest to as: like, nuova, bd, ornaments, undergraduates, when, lds, cautions,
# Nearest to more: less, most, very, greater, longer, rather, better, smaller,
# Nearest to two: four, three, five, six, seven, eight, one, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
print (two_d_embeddings.shape)
# Out:
# (400, 2)

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def CBOW_generate_batch(batch_size, num_skips, skip_window):
                    ## 8 ,      2,         1
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size,num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)    
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        labels[i, 0] = buffer[skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i, j] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [di for di in data[:6]])
print('data:', [reverse_dictionary[di] for di in data[:6]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = CBOW_generate_batch(batch_size=4, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[nei] for nei in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li[0]] for li in labels])
# Out:
# data: [5239, 3084, 12, 6, 195, 2]
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['a', 'originated'], ['as', 'term'], ['of', 'a']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['originated', 'anarchism', 'a', 'term'], ['as', 'of', 'originated', 'term'], ['as', 'abuse', 'of', 'a'], ['abuse', 'a', 'first', 'term']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed,1),
                                   train_labels, num_sampled, vocabulary_size))
    
#     tf.nn.sampled_softmax_loss(weights, biases, inputs, 
#                                labels, num_sampled, num_classes, 
#                                num_true=1, sampled_values=None, 
#                                remove_accidental_hits=True, 
#                                partition_strategy='mod', name='sampled_softmax_loss')

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 200001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = CBOW_generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.412638
# Nearest to its: reflected, rc, feature, desu, bugatti, coyotes, kane, doubled,
# Nearest to would: experimentally, shogun, hemp, urbanization, chrysler, neutralized, indeterminate, peltier,
# Nearest to most: kyi, ahl, mock, boutique, slaughtered, disagree, ubuntu, gary,
# Nearest to i: garz, intuitionism, matth, mechanistic, equalizer, preparing, fahrenheit, float,
# Nearest to not: allegiance, gtp, republics, antipope, grundgesetz, capone, erhard, terminates,
# Nearest to so: paralyzed, brightness, skeet, bridging, magisterial, ixion, agade, dad,
# Nearest to can: cookies, musically, cats, providing, floated, negev, yemen, hugh,
# Nearest to no: rankings, peoria, asceticism, entitled, glorify, dame, infect, seeming,
# Nearest to to: quintet, reorganizing, betrayal, hassan, diazepam, brave, pejorative, acetaminophen,
# Nearest to by: pulling, combats, mckenna, huber, ballet, best, charioteer, gorillas,
# Nearest to who: presocratic, velde, crop, tenants, ecclesia, footwork, haredi, gyeonggi,
# Nearest to such: sacd, wizard, abbott, tanning, keitel, spending, coins, daisies,
# Nearest to as: tm, reruns, welcomed, starch, shunning, ear, putatively, jude,
# Nearest to at: occultist, salah, brokers, dove, amharic, characterize, enlarging, moravian,
# Nearest to five: kyrgyz, mysticeti, shield, sabrina, sanctions, extortion, cemac, torrey,
# Nearest to be: communaut, kemerovo, exec, lobe, brant, stapleton, afer, sentiment,
# Average loss at step 2000: 4.120486
# Average loss at step 4000: 3.513645
# Average loss at step 6000: 3.426395
# Average loss at step 8000: 3.372212
# Average loss at step 10000: 3.296854
# Nearest to its: their, his, the, numeric, depot, etsi, her, mcdonough,
# Nearest to would: can, will, may, should, might, must, could, cannot,
# Nearest to most: more, proportions, castel, galician, tain, ahl, tetum, disagree,
# Nearest to i: garz, you, matth, pizan, mechanistic, fahrenheit, enigmas, nobleman,
# Nearest to not: conscripts, you, shuster, also, gtp, circulate, now, still,
# Nearest to so: cryoprotectant, sven, sfsr, hezbollah, institutions, magisterial, nacht, agade,
# Nearest to can: may, could, would, should, will, might, cannot, must,
# Nearest to no: peoria, rankings, meats, emiliano, dualism, braxton, ever, specialist,
# Nearest to to: pizarro, quintet, hamlin, must, would, orloff, intra, hassan,
# Nearest to by: with, in, was, charioteer, for, gauze, slovenian, myself,
# Nearest to who: which, he, kaddish, they, dfs, now, felsic, gyeonggi,
# Nearest to such: well, known, cno, described, werth, hunts, descend, fh,
# Nearest to as: surprisingly, hh, mindat, rangoon, jornal, usps, debunked, beijing,
# Nearest to at: in, moravian, timelines, although, characterize, mondays, enlarging, cubans,
# Nearest to five: six, three, four, eight, seven, nine, zero, one,
# Nearest to be: refer, been, were, have, dun, find, constantius, woolwich,
# Average loss at step 12000: 3.100504
# Average loss at step 14000: 3.170090
# Average loss at step 16000: 3.165173
# Average loss at step 18000: 3.111996
# Average loss at step 20000: 3.110231
# Nearest to its: their, his, her, the, your, our, nootka, mcdonough,
# Nearest to would: will, can, may, might, could, must, should, cannot,
# Nearest to most: more, some, many, proportions, less, adipose, ahl, fleets,
# Nearest to i: mechanistic, we, garz, you, noa, pernoud, nobleman, ii,
# Nearest to not: still, often, always, usually, also, conscripts, never, thursdays,
# Nearest to so: nuns, nacht, sven, hezbollah, sfsr, reflex, defamation, besson,
# Nearest to can: may, will, could, would, should, might, cannot, must,
# Nearest to no: a, any, solenoid, dualism, braxton, castlevania, meats, peoria,
# Nearest to to: cannot, will, squaring, townsfolk, shockley, bohr, would, pizarro,
# Nearest to by: charioteer, when, after, vow, with, slovenian, recounting, from,
# Nearest to who: he, they, which, dfs, riley, bail, murr, keyser,
# Nearest to such: well, these, known, follows, many, regarded, werth, likud,
# Nearest to as: parc, raptor, surprisingly, runoff, lookup, reruns, exclude, bridgewater,
# Nearest to at: moravian, timelines, characterize, cubans, in, during, grove, under,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to be: been, refer, have, was, find, is, describe, woolwich,
# Average loss at step 22000: 3.147481
# Average loss at step 24000: 3.062801
# Average loss at step 26000: 3.039744
# Average loss at step 28000: 3.001309
# Average loss at step 30000: 2.973101
# Nearest to its: their, his, the, our, her, etsi, your, prana,
# Nearest to would: will, may, can, could, must, might, should, cannot,
# Nearest to most: more, less, proportions, among, fleets, some, adipose, especially,
# Nearest to i: we, you, ii, they, banded, mechanistic, he, nobleman,
# Nearest to not: never, always, still, otherwise, kpd, now, thursdays, usually,
# Nearest to so: sometimes, thus, sfsr, hezbollah, bankruptcies, nacht, golda, nuns,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to no: any, only, another, solenoid, peoria, miscarriages, mechanosynthesis, begun,
# Nearest to to: will, reorganizing, townsfolk, should, hamlin, must, bohr, sentries,
# Nearest to by: myself, during, when, charioteer, slovenian, for, including, recounting,
# Nearest to who: he, also, cohn, which, never, she, often, riley,
# Nearest to such: well, known, follows, these, certain, described, many, tumors,
# Nearest to as: like, raptor, botticelli, armando, parc, rangoon, for, melodrama,
# Nearest to at: during, under, in, timelines, after, moravian, upon, on,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to be: refer, been, being, have, contain, become, describe, were,
# Average loss at step 32000: 2.966889
# Average loss at step 34000: 2.997541
# Average loss at step 36000: 2.856284
# Average loss at step 38000: 2.933995
# Average loss at step 40000: 2.934027
# Nearest to its: their, his, her, our, the, numeric, etsi, displeasure,
# Nearest to would: could, will, can, may, might, must, should, cannot,
# Nearest to most: more, some, less, many, among, very, brownlow, especially,
# Nearest to i: ii, you, we, they, t, banded, xf, overdosing,
# Nearest to not: never, now, always, offseason, generally, otherwise, still, thursdays,
# Nearest to so: sometimes, providers, bankruptcies, sfsr, nuns, thus, golda, suggested,
# Nearest to can: may, could, would, will, should, must, cannot, might,
# Nearest to no: another, any, braxton, christianized, mechanosynthesis, solenoid, christa, little,
# Nearest to to: must, would, will, reorganizing, should, might, impeached, acetaminophen,
# Nearest to by: during, with, slovenian, from, through, under, without, after,
# Nearest to who: he, often, she, they, cohn, that, keyser, also,
# Nearest to such: well, these, known, follows, certain, cno, regarded, described,
# Nearest to as: stately, lightness, injurious, tm, surprisingly, raptor, parc, plantarum,
# Nearest to at: during, in, after, under, upon, within, before, moravian,
# Nearest to five: seven, six, four, eight, zero, nine, three, two,
# Nearest to be: refer, been, have, become, being, was, were, are,
# Average loss at step 42000: 2.898880
# Average loss at step 44000: 2.823545
# Average loss at step 46000: 2.819954
# Average loss at step 48000: 2.857172
# Average loss at step 50000: 2.884171
# Nearest to its: their, his, our, her, the, displeasure, your, misandry,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to most: more, less, many, especially, among, very, galician, auditing,
# Nearest to i: ii, you, we, g, never, they, cohn, shoshone,
# Nearest to not: now, never, still, usually, offseason, generally, always, rarely,
# Nearest to so: thus, nuns, sometimes, vista, too, phonemic, providers, sfsr,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to no: any, another, a, solenoid, mechanosynthesis, miscarriages, begun, forks,
# Nearest to to: will, would, should, could, hamlin, cannot, must, might,
# Nearest to by: through, gauze, without, with, when, rien, boast, recounting,
# Nearest to who: he, they, she, which, typically, generally, often, keyser,
# Nearest to such: these, well, known, follows, certain, regarded, colorful, many,
# Nearest to as: raptor, mister, surprisingly, consciously, parc, like, monolithic, fingerprints,
# Nearest to at: in, during, under, near, on, moravian, before, kun,
# Nearest to five: six, seven, eight, zero, four, three, two, nine,
# Nearest to be: refer, been, have, become, being, weep, is, were,
# Average loss at step 52000: 2.809991
# Average loss at step 54000: 2.783044
# Average loss at step 56000: 2.889305
# Average loss at step 58000: 2.875456
# Average loss at step 60000: 2.742679
# Nearest to its: their, his, her, our, the, depot, your, displeasure,
# Nearest to would: could, will, might, can, should, must, may, cannot,
# Nearest to most: more, many, less, especially, some, galician, proportions, very,
# Nearest to i: ii, we, you, they, banded, g, nobleman, sierpinski,
# Nearest to not: now, never, still, actually, generally, always, conscripts, lamps,
# Nearest to so: too, thus, sometimes, if, nuns, deceased, schultz, providers,
# Nearest to can: may, could, must, will, would, should, cannot, might,
# Nearest to no: any, another, begun, little, solenoid, mechanosynthesis, always, gibb,
# Nearest to to: would, might, should, bohr, must, could, reorganizing, quintet,
# Nearest to by: through, charioteer, during, when, glittering, gauze, after, without,
# Nearest to who: he, which, generally, often, cohn, they, she, also,
# Nearest to such: well, known, follows, these, certain, described, regarded, cno,
# Nearest to as: like, surprisingly, runoff, particularly, moria, lookup, lightness, overheat,
# Nearest to at: during, in, near, under, kun, indefensible, after, moravian,
# Nearest to five: six, four, eight, seven, three, two, nine, zero,
# Nearest to be: become, refer, been, have, was, weep, remain, is,
# Average loss at step 62000: 2.823887
# Average loss at step 64000: 2.782268
# Average loss at step 66000: 2.809024
# Average loss at step 68000: 2.829318
# Average loss at step 70000: 2.719738
# Nearest to its: their, his, our, her, the, whose, relics, depot,
# Nearest to would: will, could, might, should, can, may, must, cannot,
# Nearest to most: more, many, especially, some, less, proportions, particularly, both,
# Nearest to i: ii, we, you, g, darby, banded, they, mail,
# Nearest to not: never, now, still, always, actually, offseason, generally, otherwise,
# Nearest to so: too, sometimes, how, vantaa, thus, providers, therefore, cliff,
# Nearest to can: could, will, may, should, must, would, cannot, might,
# Nearest to no: any, mechanosynthesis, another, nothing, gibb, sputnik, little, solenoid,
# Nearest to to: hamlin, might, appease, hassan, bohr, townsfolk, towards, must,
# Nearest to by: through, charioteer, juneau, without, recounting, minogue, slovenian, brion,
# Nearest to who: often, generally, which, also, he, usually, still, actually,
# Nearest to such: well, follows, these, known, cno, certain, serve, many,
# Nearest to as: including, raptor, surprisingly, stately, rangoon, lightness, lubricating, like,
# Nearest to at: during, near, removes, within, piaget, in, on, indefensible,
# Nearest to five: six, four, seven, three, eight, zero, two, nine,
# Nearest to be: refer, been, being, become, get, is, attain, was,
# Average loss at step 72000: 2.793643
# Average loss at step 74000: 2.767166
# Average loss at step 76000: 2.624983
# Average loss at step 78000: 2.337285
# Average loss at step 80000: 2.561359
# Nearest to its: their, his, her, our, whose, the, depot, illustrious,
# Nearest to would: could, will, might, must, should, can, may, cannot,
# Nearest to most: more, less, many, some, especially, particularly, use, galician,
# Nearest to i: ii, we, you, nobleman, banded, darby, hideous, sierpinski,
# Nearest to not: never, now, actually, always, still, generally, offseason, t,
# Nearest to so: too, sometimes, thus, therefore, how, if, then, beyond,
# Nearest to can: could, must, will, should, cannot, would, might, may,
# Nearest to no: any, little, solenoid, nothing, mechanosynthesis, another, braxton, miscarriages,
# Nearest to to: would, could, for, must, cannot, reorganizing, towards, will,
# Nearest to by: through, with, when, recounting, from, using, featuring, without,
# Nearest to who: often, he, which, she, usually, also, generally, actually,
# Nearest to such: well, known, these, certain, many, follows, regarded, listed,
# Nearest to as: injurious, stately, tm, wick, lookup, mehr, nipple, mister,
# Nearest to at: near, in, during, moravian, on, after, removes, crowded,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to be: being, become, been, refer, have, remain, were, fully,
# Average loss at step 82000: 2.711952
# Average loss at step 84000: 2.683431
# Average loss at step 86000: 2.789794
# Average loss at step 88000: 2.719886
# Average loss at step 90000: 2.637318
# Nearest to its: their, his, her, our, whose, the, depot, em,
# Nearest to would: could, will, might, must, can, should, may, cannot,
# Nearest to most: more, less, many, especially, some, particularly, throughout, among,
# Nearest to i: we, ii, you, they, never, darby, nobleman, banded,
# Nearest to not: never, actually, always, still, otherwise, gratitude, rarely, now,
# Nearest to so: too, sometimes, therefore, thus, then, jujutsu, vista, beyond,
# Nearest to can: could, will, must, should, might, would, cannot, may,
# Nearest to no: any, solenoid, little, another, begun, nothing, mechanosynthesis, miscarriages,
# Nearest to to: should, might, must, reorganizing, will, cannot, would, can,
# Nearest to by: through, charioteer, using, potent, with, recounting, flaps, without,
# Nearest to who: he, actually, cohn, they, she, still, typically, dfs,
# Nearest to such: well, known, these, regarded, follows, listed, certain, mentioned,
# Nearest to as: after, stately, raptor, parc, catchy, reverts, when, lightness,
# Nearest to at: during, near, in, removes, moravian, amharic, on, piaget,
# Nearest to five: four, three, six, seven, eight, two, zero, nine,
# Nearest to be: become, refer, been, have, get, contain, being, remain,
# Average loss at step 92000: 2.747668
# Average loss at step 94000: 2.770715
# Average loss at step 96000: 2.738662
# Average loss at step 98000: 2.415933
# Average loss at step 100000: 2.662835
# Nearest to its: their, his, her, whose, our, the, your, angra,
# Nearest to would: could, will, might, should, must, can, cannot, may,
# Nearest to most: more, less, particularly, especially, among, many, some, throughout,
# Nearest to i: ii, we, you, darby, g, they, never, banded,
# Nearest to not: never, still, always, actually, now, rarely, you, otherwise,
# Nearest to so: too, wrong, indeed, therefore, simply, sometimes, nuns, stupidity,
# Nearest to can: could, will, must, cannot, should, might, would, may,
# Nearest to no: any, solenoid, mechanosynthesis, none, nothing, soe, little, sputnik,
# Nearest to to: will, must, appease, could, help, acetaminophen, cannot, shockley,
# Nearest to by: through, using, without, during, from, potent, via, when,
# Nearest to who: often, he, which, actually, usually, typically, they, she,
# Nearest to such: well, known, regarded, these, listed, certain, described, serves,
# Nearest to as: rangoon, armando, including, raptor, because, rickshaws, mellow, plantarum,
# Nearest to at: during, near, within, under, upon, in, after, kun,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to be: get, become, been, refer, being, remain, have, contain,
# Average loss at step 102000: 2.632395
# Average loss at step 104000: 2.701658
# Average loss at step 106000: 2.689539
# Average loss at step 108000: 2.744715
# Average loss at step 110000: 2.680886
# Nearest to its: their, his, her, our, whose, the, your, twister,
# Nearest to would: will, could, might, should, can, must, may, cannot,
# Nearest to most: more, many, less, particularly, increasingly, among, especially, some,
# Nearest to i: ii, we, you, g, they, iii, studd, banded,
# Nearest to not: never, now, always, actually, rarely, otherwise, still, almost,
# Nearest to so: too, hata, therefore, bankruptcies, besson, vantaa, beyond, sometimes,
# Nearest to can: could, cannot, must, should, may, will, might, would,
# Nearest to no: any, nothing, little, solenoid, mechanosynthesis, none, pero, sputnik,
# Nearest to to: will, must, should, roundly, reorganizing, townsfolk, would, towards,
# Nearest to by: through, without, including, during, using, recounting, charioteer, rien,
# Nearest to who: she, often, he, actually, still, generally, typically, traditionally,
# Nearest to such: well, known, certain, regarded, these, listed, described, serve,
# Nearest to as: stately, injurious, lightness, fascists, when, surprisingly, incidental, marshlands,
# Nearest to at: during, near, crowded, indefensible, under, in, within, piaget,
# Nearest to five: four, seven, six, eight, three, two, zero, nine,
# Nearest to be: been, get, become, refer, being, remain, was, construct,
# Average loss at step 112000: 2.677781
# Average loss at step 114000: 2.632292
# Average loss at step 116000: 2.655198
# Average loss at step 118000: 2.588872
# Average loss at step 120000: 2.682510
# Nearest to its: their, his, whose, her, the, our, depot, secretaries,
# Nearest to would: could, will, might, should, must, can, may, cannot,
# Nearest to most: more, less, particularly, many, among, especially, some, dreadful,
# Nearest to i: ii, we, you, iii, darby, vi, iv, they,
# Nearest to not: never, now, nor, always, still, also, actually, otherwise,
# Nearest to so: too, sometimes, beyond, indeed, besson, sparsely, jacobs, wrong,
# Nearest to can: could, must, cannot, may, should, might, will, would,
# Nearest to no: any, nothing, little, solenoid, miscarriages, mechanosynthesis, none, traditionally,
# Nearest to to: reorganizing, patel, could, should, towards, hamlin, would, help,
# Nearest to by: through, charioteer, using, recounting, with, without, flaps, including,
# Nearest to who: often, still, actually, generally, which, typically, usually, she,
# Nearest to such: well, these, certain, known, listed, regarded, including, serve,
# Nearest to as: injurious, armando, chulainn, mellow, ominous, ghostbusters, kripke, fascists,
# Nearest to at: during, in, near, under, within, piaget, removes, moravian,
# Nearest to five: four, seven, eight, six, three, zero, two, nine,
# Nearest to be: been, become, get, refer, remain, being, was, attain,
# Average loss at step 122000: 2.659910
# Average loss at step 124000: 2.699946
# Average loss at step 126000: 2.678087
# Average loss at step 128000: 2.542861
# Average loss at step 130000: 2.691451
# Nearest to its: their, his, whose, her, the, our, angra, parental,
# Nearest to would: could, might, will, must, should, can, may, cannot,
# Nearest to most: more, less, particularly, especially, fleets, among, many, consequences,
# Nearest to i: ii, we, you, iii, g, darby, mail, telling,
# Nearest to not: never, always, now, otherwise, usually, still, rarely, nor,
# Nearest to so: too, indeed, sometimes, vantaa, rename, divider, beyond, therefore,
# Nearest to can: could, will, cannot, must, may, should, might, would,
# Nearest to no: any, nothing, solenoid, little, always, become, none, mechanosynthesis,
# Nearest to to: must, would, will, should, towards, could, reorganizing, might,
# Nearest to by: through, without, charioteer, using, with, potent, ligurian, jhanas,
# Nearest to who: usually, generally, often, typically, actually, always, still, also,
# Nearest to such: well, these, serve, listed, certain, known, regarded, follows,
# Nearest to as: surprisingly, including, raptor, armando, plunging, rickshaws, denard, tm,
# Nearest to at: during, near, in, within, indefensible, moravian, ldl, removes,
# Nearest to five: six, seven, four, eight, three, two, nine, zero,
# Nearest to be: get, been, become, attain, refer, remain, being, have,
# Average loss at step 132000: 2.614564
# Average loss at step 134000: 2.575270
# Average loss at step 136000: 2.600129
# Average loss at step 138000: 2.582162
# Average loss at step 140000: 2.485351
# Nearest to its: their, his, the, whose, her, our, depot, twister,
# Nearest to would: might, could, will, should, can, may, must, cannot,
# Nearest to most: less, many, more, particularly, especially, some, both, increasingly,
# Nearest to i: ii, we, mail, g, iii, you, darby, papuan,
# Nearest to not: never, now, always, still, rarely, otherwise, generally, shakur,
# Nearest to so: too, indeed, spontaneously, sometimes, beyond, therefore, nuns, schultz,
# Nearest to can: could, cannot, may, must, should, will, might, would,
# Nearest to no: any, nothing, none, little, solenoid, sculpting, wad, mesh,
# Nearest to to: toward, should, reorganizing, patel, help, towards, must, appease,
# Nearest to by: through, including, without, recounting, charioteer, berliners, philological, via,
# Nearest to who: still, he, actually, which, generally, usually, often, typically,
# Nearest to such: well, these, serve, certain, known, listed, act, regarded,
# Nearest to as: surprisingly, including, raptor, armando, fingerprints, untrue, botticelli, ventricular,
# Nearest to at: during, near, under, moravian, inerrancy, illustrates, cubans, besides,
# Nearest to five: six, four, three, eight, seven, zero, nine, two,
# Nearest to be: been, attain, remain, get, become, being, refer, weep,
# Average loss at step 142000: 2.465622
# Average loss at step 144000: 2.560849
# Average loss at step 146000: 2.569528
# Average loss at step 148000: 2.540460
# Average loss at step 150000: 2.587206
# Nearest to its: their, his, her, whose, the, our, your, angra,
# Nearest to would: will, might, could, can, may, should, must, cannot,
# Nearest to most: more, less, particularly, many, especially, some, dreadful, clubhouse,
# Nearest to i: we, ii, g, you, mail, mechanistic, punta, iii,
# Nearest to not: never, always, still, now, nor, actually, usually, generally,
# Nearest to so: nuns, too, besson, indeed, beyond, rename, sometimes, stressed,
# Nearest to can: could, cannot, may, must, might, will, should, would,
# Nearest to no: nothing, any, little, solenoid, mechanosynthesis, none, pero, sputnik,
# Nearest to to: will, would, patel, reorganizing, basayev, cannot, hamlin, could,
# Nearest to by: through, charioteer, using, including, when, from, without, recounting,
# Nearest to who: he, still, often, she, actually, cohn, whom, abortive,
# Nearest to such: well, these, listed, known, regarded, act, certain, follows,
# Nearest to as: including, like, injurious, surprisingly, bridgewater, mehr, ventricular, ominous,
# Nearest to at: under, during, near, in, kopp, daemons, moravian, gyeongsang,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to be: been, get, remain, refer, attain, become, being, construct,
# Average loss at step 152000: 2.613989
# Average loss at step 154000: 2.576927
# Average loss at step 156000: 2.534753
# Average loss at step 158000: 2.556721
# Average loss at step 160000: 2.527868
# Nearest to its: their, his, whose, her, the, our, angra, diplomatic,
# Nearest to would: might, could, will, may, can, should, must, cannot,
# Nearest to most: more, less, especially, particularly, extremely, throughout, oldest, increasingly,
# Nearest to i: we, ii, you, g, mail, they, punta, landholders,
# Nearest to not: never, always, now, otherwise, actually, nor, still, rarely,
# Nearest to so: too, thus, indeed, therefore, beyond, eventually, exceeds, sometimes,
# Nearest to can: could, may, cannot, might, should, will, must, would,
# Nearest to no: any, nothing, little, mechanosynthesis, none, solenoid, pero, git,
# Nearest to to: reorganizing, help, will, patel, roundly, townsfolk, tutsi, appease,
# Nearest to by: potent, charioteer, through, during, without, including, flaps, when,
# Nearest to who: he, often, typically, actually, cohn, still, also, justifiably,
# Nearest to such: well, known, certain, these, serve, follows, listed, mentioned,
# Nearest to as: armando, injurious, like, surprisingly, raptor, marshlands, including, mctaggart,
# Nearest to at: during, near, under, in, within, indefensible, moravian, on,
# Nearest to five: four, seven, six, eight, three, zero, two, nine,
# Nearest to be: get, been, refer, attain, contain, remain, being, construct,
# Average loss at step 162000: 2.535610
# Average loss at step 164000: 2.584427
# Average loss at step 166000: 2.435500
# Average loss at step 168000: 2.547218
# Average loss at step 170000: 2.546163
# Nearest to its: their, his, our, whose, her, the, parental, creativity,
# Nearest to would: might, could, will, should, can, must, may, cannot,
# Nearest to most: more, especially, particularly, less, many, some, dreadful, consequences,
# Nearest to i: ii, you, iii, darby, iv, mail, v, we,
# Nearest to not: never, now, always, rarely, otherwise, nor, still, t,
# Nearest to so: too, therefore, indeed, exceeds, vantaa, beyond, thus, spontaneously,
# Nearest to can: could, cannot, may, should, must, might, will, would,
# Nearest to no: any, little, nothing, christa, another, none, mechanosynthesis, solenoid,
# Nearest to to: will, help, should, reorganizing, must, might, could, cannot,
# Nearest to by: without, charioteer, through, during, servicio, including, stern, under,
# Nearest to who: typically, often, he, cohn, generally, actually, whom, still,
# Nearest to such: these, well, certain, known, follows, serve, regarded, listed,
# Nearest to as: surprisingly, lightness, tm, injurious, raptor, fascists, seamstress, maka,
# Nearest to at: during, near, in, moravian, under, indefensible, within, hasn,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to be: get, been, refer, attain, being, remain, contain, become,
# Average loss at step 172000: 2.513098
# Average loss at step 174000: 2.476118
# Average loss at step 176000: 2.433255
# Average loss at step 178000: 2.492142
# Average loss at step 180000: 2.544558
# Nearest to its: their, his, her, whose, our, the, diplomatic, misandry,
# Nearest to would: might, could, will, should, can, may, must, cannot,
# Nearest to most: more, less, many, particularly, especially, some, increasingly, several,
# Nearest to i: ii, you, we, iii, mail, they, iv, darby,
# Nearest to not: never, now, rarely, nor, still, actually, always, legally,
# Nearest to so: too, beyond, exceeds, vantaa, indeed, therefore, spontaneously, thus,
# Nearest to can: could, cannot, will, must, might, may, should, would,
# Nearest to no: any, nothing, scarcely, solenoid, another, none, begun, omens,
# Nearest to to: toward, hamlin, will, reorganizing, might, could, roundly, batches,
# Nearest to by: without, including, via, flaps, charioteer, through, stern, with,
# Nearest to who: he, typically, generally, conceals, still, she, keyser, often,
# Nearest to such: well, these, known, follows, serve, act, certain, qualify,
# Nearest to as: raptor, like, mctaggart, surprisingly, including, when, armando, marshlands,
# Nearest to at: near, during, in, under, moravian, functionaries, before, indefensible,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to be: been, refer, become, attain, being, get, produce, remain,
# Average loss at step 182000: 2.431877
# Average loss at step 184000: 2.506775
# Average loss at step 186000: 2.549663
# Average loss at step 188000: 2.558687
# Average loss at step 190000: 2.411033
# Nearest to its: their, her, his, whose, our, the, diplomatic, creativity,
# Nearest to would: could, might, will, should, can, must, may, cannot,
# Nearest to most: more, many, less, particularly, especially, some, throughout, both,
# Nearest to i: we, ii, they, you, shoshone, iii, banded, mail,
# Nearest to not: never, actually, rarely, still, now, legally, nor, almost,
# Nearest to so: too, beyond, therefore, exceeds, indeed, spontaneously, thus, linemen,
# Nearest to can: could, cannot, should, must, might, may, will, would,
# Nearest to no: any, nothing, none, scarcely, little, solenoid, eurocents, another,
# Nearest to to: reorganizing, patel, columbians, toward, towards, slack, might, should,
# Nearest to by: through, charioteer, including, during, without, via, recounting, from,
# Nearest to who: he, generally, whom, typically, which, also, justifiably, cohn,
# Nearest to such: well, certain, known, serve, follows, listed, evidenced, act,
# Nearest to as: surprisingly, tm, like, particularly, raptor, injurious, ominous, underwent,
# Nearest to at: during, near, under, in, piaget, moravian, indefensible, bursting,
# Nearest to five: six, four, seven, eight, three, two, nine, zero,
# Nearest to be: been, become, remain, get, attain, produce, refer, pursue,
# Average loss at step 192000: 2.537802
# Average loss at step 194000: 2.480639
# Average loss at step 196000: 2.506560
# Average loss at step 198000: 2.530438
# Average loss at step 200000: 2.452556
# Nearest to its: their, his, whose, her, our, the, authoritarianism, appeasement,
# Nearest to would: will, might, could, should, may, can, must, cannot,
# Nearest to most: more, many, some, especially, less, particularly, fleets, throughout,
# Nearest to i: ii, we, you, g, darby, iii, mail, banded,
# Nearest to not: never, actually, now, always, rarely, legally, nor, still,
# Nearest to so: too, indeed, beyond, vantaa, sometimes, how, therefore, aung,
# Nearest to can: will, should, must, could, cannot, might, may, would,
# Nearest to no: any, none, nothing, little, mechanosynthesis, sputnik, scarcely, teletype,
# Nearest to to: might, reorganizing, will, bannister, patel, vilna, swapping, headgear,
# Nearest to by: through, including, via, without, charioteer, democratique, sinusoidal, when,
# Nearest to who: which, typically, still, often, generally, whom, he, actually,
# Nearest to such: well, follows, known, serve, having, qualify, these, listed,
# Nearest to as: like, raptor, mellow, surprisingly, similarly, including, armando, botticelli,
# Nearest to at: near, during, removes, piaget, around, in, on, moravian,
# Nearest to five: six, four, three, seven, eight, zero, two, nine,
# Nearest to be: attain, get, been, become, refer, being, accommodate, remain,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
print (two_d_embeddings.shape)
# Out:
# (400, 2)

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
